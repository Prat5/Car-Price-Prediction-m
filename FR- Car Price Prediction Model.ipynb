# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import plotly.express as px
import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv('Car_Details_Final.csv')
df
# Out:
#        Unnamed: 0  Brand              Model                        Variant  \
# 0               0   Audi                 A4               2.0 TDI (143bhp)
# 1               1   Audi                 A8                3.0 TDI quattro
# 2               2   Audi                 Q3             2.0 TDI Base Grade
# 3               3   Audi                 A3                 35 TDI Premium
# 4               4   Audi                 Q3  35 TDI Premium Plus + Sunroof
# ...           ...    ...                ...                            ...
# 18336       18336  Volvo                S60                 T4 Inscription
# 18337       18337  Volvo               XC90                         D5 AWD
# 18338       18338  Volvo               XC60        Inscription [2017-2020]
# 18339       18339  Volvo  V90 Cross Country     D5 Inscription [2017-2020]
# 18340       18340  Volvo               XC60        Inscription [2017-2020]
#
# ...

# %% [markdown]
# ### Preprocessing

# %%
df.drop('Unnamed: 0',axis = 1,inplace=True)
df
# Out:
#        Brand              Model                        Variant  Year  \
# 0       Audi                 A4               2.0 TDI (143bhp)  2015
# 1       Audi                 A8                3.0 TDI quattro  2009
# 2       Audi                 Q3             2.0 TDI Base Grade  2012
# 3       Audi                 A3                 35 TDI Premium  2018
# 4       Audi                 Q3  35 TDI Premium Plus + Sunroof  2014
# ...      ...                ...                            ...   ...
# 18336  Volvo                S60                 T4 Inscription  2022
# 18337  Volvo               XC90                         D5 AWD  2010
# 18338  Volvo               XC60        Inscription [2017-2020]  2018
# 18339  Volvo  V90 Cross Country     D5 Inscription [2017-2020]  2018
# 18340  Volvo               XC60        Inscription [2017-2020]  2018
#
#       Transmission  KMs Driven No. of Owners Fuel Type       City       Price
# ...

# %% [markdown]
# ### Year

# %%
df['Years Old'] = 2022 - df['Year']

# %%
df
# Out:
#        Brand              Model                        Variant  Year  \
# 0       Audi                 A4               2.0 TDI (143bhp)  2015
# 1       Audi                 A8                3.0 TDI quattro  2009
# 2       Audi                 Q3             2.0 TDI Base Grade  2012
# 3       Audi                 A3                 35 TDI Premium  2018
# 4       Audi                 Q3  35 TDI Premium Plus + Sunroof  2014
# ...      ...                ...                            ...   ...
# 18336  Volvo                S60                 T4 Inscription  2022
# 18337  Volvo               XC90                         D5 AWD  2010
# 18338  Volvo               XC60        Inscription [2017-2020]  2018
# 18339  Volvo  V90 Cross Country     D5 Inscription [2017-2020]  2018
# 18340  Volvo               XC60        Inscription [2017-2020]  2018
#
#       Transmission  KMs Driven No. of Owners Fuel Type       City       Price  \
# ...

# %%
df.drop('Year',axis=1,inplace=True)

# %%
df
# Out:
#        Brand              Model                        Variant Transmission  \
# 0       Audi                 A4               2.0 TDI (143bhp)    Automatic
# 1       Audi                 A8                3.0 TDI quattro    Automatic
# 2       Audi                 Q3             2.0 TDI Base Grade    Automatic
# 3       Audi                 A3                 35 TDI Premium    Automatic
# 4       Audi                 Q3  35 TDI Premium Plus + Sunroof    Automatic
# ...      ...                ...                            ...          ...
# 18336  Volvo                S60                 T4 Inscription    Automatic
# 18337  Volvo               XC90                         D5 AWD    Automatic
# 18338  Volvo               XC60        Inscription [2017-2020]    Automatic
# 18339  Volvo  V90 Cross Country     D5 Inscription [2017-2020]    Automatic
# 18340  Volvo               XC60        Inscription [2017-2020]    Automatic
#
# ...

# %% [markdown]
# ##### No. of Owners

# %%
df['No. of Owners'].unique()
# Out:
# array(['First', 'Second', 'UnRegistered Car', 'Third', '4 or More',
#        'Fourth'], dtype=object)

# %%
df['No. of Owners'] = df['No. of Owners'].replace(['First','Second','Fourth','Third','4 or More','UnRegistered Car'],[1,2,4,3,5,0])

# %%
df['No. of Owners'].unique()
# Out:
# array([1, 2, 0, 3, 5, 4], dtype=int64)

# %%
df
# Out:
#        Brand              Model                        Variant Transmission  \
# 0       Audi                 A4               2.0 TDI (143bhp)    Automatic
# 1       Audi                 A8                3.0 TDI quattro    Automatic
# 2       Audi                 Q3             2.0 TDI Base Grade    Automatic
# 3       Audi                 A3                 35 TDI Premium    Automatic
# 4       Audi                 Q3  35 TDI Premium Plus + Sunroof    Automatic
# ...      ...                ...                            ...          ...
# 18336  Volvo                S60                 T4 Inscription    Automatic
# 18337  Volvo               XC90                         D5 AWD    Automatic
# 18338  Volvo               XC60        Inscription [2017-2020]    Automatic
# 18339  Volvo  V90 Cross Country     D5 Inscription [2017-2020]    Automatic
# 18340  Volvo               XC60        Inscription [2017-2020]    Automatic
#
# ...

# %% [markdown]
# #### Fuel Type

# %%
df['Fuel Type'].unique()
# Out:
# array(['Diesel', 'Petrol', 'Diesel + Diesel', 'Petrol + Petrol',
#        'Petrol + CNG', 'Diesel + Petrol', 'CNG', 'Diesel + CNG', 'Hybrid',
#        'Electric', 'Electric + Electric', 'Electric + CNG',
#        'Diesel + LPG', 'Hybrid + CNG', 'CNG + CNG', 'LPG + Petrol+Lpg',
#        'Petrol + LPG', 'LPG', 'Hybrid + Hybrid(Ele', 'Petrol + Diesel',
#        'LPG + LPG', 'CNG + Petrol+Cng'], dtype=object)

# %%
df['Fuel Type'] = df['Fuel Type'].replace('Diesel + Diesel','Diesel')
df['Fuel Type'] = df['Fuel Type'].replace('Petrol + Petrol','Petrol')
df['Fuel Type'] = df['Fuel Type'].replace('LPG + LPG','LPG')
df['Fuel Type'] = df['Fuel Type'].replace('Electric + Electric','Electric')
df['Fuel Type'] = df['Fuel Type'].replace('CNG + CNG','CNG')
df['Fuel Type'] = df['Fuel Type'].replace('LPG + Petrol+Lpg','Petrol + LPG')
df['Fuel Type'] = df['Fuel Type'].replace('CNG + Petrol+Cng','Petrol + CNG')
df['Fuel Type'] = df['Fuel Type'].replace('Hybrid + Hybrid(Ele','Hybrid')

# %%
df = df[df['Fuel Type']!='Diesel + Petrol']

# %%
df = df[df['Fuel Type']!='Petrol + Diesel']

# %%
df = df[df['Fuel Type']!='Electric + CNG']

# %%
df = df[df['Fuel Type'] !='Hybrid + CNG']

# %%
df['Fuel Type'].unique()
# Out:
# array(['Diesel', 'Petrol', 'Petrol + CNG', 'CNG', 'Diesel + CNG',
#        'Hybrid', 'Electric', 'Diesel + LPG', 'Petrol + LPG', 'LPG'],
#       dtype=object)

# %%
df
# Out:
#        Brand              Model                        Variant Transmission  \
# 0       Audi                 A4               2.0 TDI (143bhp)    Automatic
# 1       Audi                 A8                3.0 TDI quattro    Automatic
# 2       Audi                 Q3             2.0 TDI Base Grade    Automatic
# 3       Audi                 A3                 35 TDI Premium    Automatic
# 4       Audi                 Q3  35 TDI Premium Plus + Sunroof    Automatic
# ...      ...                ...                            ...          ...
# 18336  Volvo                S60                 T4 Inscription    Automatic
# 18337  Volvo               XC90                         D5 AWD    Automatic
# 18338  Volvo               XC60        Inscription [2017-2020]    Automatic
# 18339  Volvo  V90 Cross Country     D5 Inscription [2017-2020]    Automatic
# 18340  Volvo               XC60        Inscription [2017-2020]    Automatic
#
# ...

# %% [markdown]
# ##### City

# %%
df['City'].unique()
# Out:
# array(['Ahmedabad', 'Chandigarh', 'Pune', 'Mumbai', 'Surat', 'Bangalore',
#        'Gandhi Nagar', 'Maninagar', 'Chennai', 'Dehradun', 'Udupi',
#        'Tumkur', 'Coimbatore', 'Mohali', 'Madurai', 'Ambattur',
#        'Tiruchirappalli', 'Velachery', 'Faridabad', 'Delhi', 'Gurgaon',
#        'Sonepat', 'Lucknow', 'Agra', 'Ghaziabad', 'Noida', 'Ludhiana',
#        'Bulandshahar', 'Muzaffarnagar', 'Meerut', 'Charkhi Dadri',
#        'Hyderabad', 'Secunderabad', 'Khairtabad', 'Warangal', 'Kolkata',
#        'Habra', 'Baharampur', 'Barackpore', 'Dankuni',
#        'North 24 Parganas', 'Navi Mumbai', 'Thane', 'Panvel',
#        'Ulhasnagar', 'Kalyan', 'Pimpri-Chinchwad', 'Lonavla', 'Raigad'],
#       dtype=object)

# %%
df['City'] = df['City'].replace(['Habra', 'Baharampur', 'Dankuni', 'North 24 Parganas','Barackpore'],'Kolkata')

# %%
df['City'] = df['City'].replace(['Gandhi Nagar', 'Maninagar','Surat'],'Ahmedabad')

# %%
df['City'] = df['City'].replace(['Secunderabad', 'Khairtabad','Sahibabad','Khairtabad','Warangal'],'Hyderabad')

# %%
df['City'] = df['City'].replace(['Madurai', 'Ambattur','Tiruchirappalli', 'Velachery','Coimbatore'],'Chennai')

# %%
df['City'] = df['City'].replace(['Thane','Dombivali', 'Navi Mumbai', 'Panvel', 'Kalyan', 'Ulhasnagar','Badlapur', 'Vasai'],'Mumbai')

# %%
df['City'] = df['City'].replace(['Alandi','Pimpri-Chinchwad','Lonavla', 'Raigad'],'Pune')

# %%
df['City'] = df['City'].replace(['Bangalore','Tumkur','Udupi'],'Bengaluru')

# %%
df['City'] = df['City'].replace(['Faridabad', 'Gurgaon', 'Mohali', 'Chandigarh', 'Sonepat','Dehradun', 'Lucknow', 'Agra', 'Ghaziabad', 'Noida', 'Ludhiana', 'Bulandshahar', 'Muzaffarnagar', 'Meerut', 'Charkhi Dadri'],'Delhi')

# %%
df['City'].value_counts()
# Out:
# Mumbai       3847
# Delhi        3541
# Hyderabad    2204
# Chennai      2033
# Pune         2019
# Bengaluru    1881
# Ahmedabad    1609
# Kolkata      1188
# Name: City, dtype: int64

# %% [markdown]
# ### Price

# %%
temp = df[df['Price'].str.contains('Crore')]
temp1 = temp.index
temp
# Out:
#                Brand              Model              Variant Transmission  \
# 46           Bentley     Continental GT                Coupe    Automatic
# 98               BMW           7-Series  740Li DPE Signature    Automatic
# 813       Land Rover  Range Rover Sport              SDV6 SE    Automatic
# 1341     Rolls-Royce              Ghost                  6.5    Automatic
# 1762             BMW           7-Series  730Ld DPE Signature    Automatic
# ...              ...                ...                  ...          ...
# 17616  Mercedes-Benz            G-Class             G 63 AMG    Automatic
# 17686        Porsche                911    Carrera Cabriolet    Automatic
# 18033         Toyota       Land Cruiser            LC 200 VX    Automatic
# 18075         Toyota       Land Cruiser            LC 200 VX    Automatic
# 18079         Toyota       Land Cruiser            LC 200 VX    Automatic
#
#        KMs Driven  No. of Owners Fuel Type       City       Price  Years Old
# ...

# %%
df['Amount'] = 1

# %%
for i in temp1:
    df['Amount'][i] = 10000000

# %%
temp = df[df['Price'].str.contains('Lakh')]
temp1 = temp.index
temp
# Out:
#        Brand              Model                        Variant Transmission  \
# 0       Audi                 A4               2.0 TDI (143bhp)    Automatic
# 1       Audi                 A8                3.0 TDI quattro    Automatic
# 2       Audi                 Q3             2.0 TDI Base Grade    Automatic
# 3       Audi                 A3                 35 TDI Premium    Automatic
# 4       Audi                 Q3  35 TDI Premium Plus + Sunroof    Automatic
# ...      ...                ...                            ...          ...
# 18336  Volvo                S60                 T4 Inscription    Automatic
# 18337  Volvo               XC90                         D5 AWD    Automatic
# 18338  Volvo               XC60        Inscription [2017-2020]    Automatic
# 18339  Volvo  V90 Cross Country     D5 Inscription [2017-2020]    Automatic
# 18340  Volvo               XC60        Inscription [2017-2020]    Automatic
#
# ...

# %%
for i in temp1:
    df['Amount'][i] = 100000

# %%
df['Price'] = df['Price'].str.replace(' Lakh','')
df['Price'] = df['Price'].str.replace(' Crore','')

# %%
df['Price'] = df['Price'].str.replace(',','')

# %%
df['Price']=df['Price'].astype(np.float64)

# %%
df['Price'] = df['Price']*df['Amount']
df.drop('Amount',axis=1,inplace=True)

# %%
df
# Out:
#        Brand              Model                        Variant Transmission  \
# 0       Audi                 A4               2.0 TDI (143bhp)    Automatic
# 1       Audi                 A8                3.0 TDI quattro    Automatic
# 2       Audi                 Q3             2.0 TDI Base Grade    Automatic
# 3       Audi                 A3                 35 TDI Premium    Automatic
# 4       Audi                 Q3  35 TDI Premium Plus + Sunroof    Automatic
# ...      ...                ...                            ...          ...
# 18336  Volvo                S60                 T4 Inscription    Automatic
# 18337  Volvo               XC90                         D5 AWD    Automatic
# 18338  Volvo               XC60        Inscription [2017-2020]    Automatic
# 18339  Volvo  V90 Cross Country     D5 Inscription [2017-2020]    Automatic
# 18340  Volvo               XC60        Inscription [2017-2020]    Automatic
#
# ...

# %% [markdown]
# ### Checking and dropping duplicate Rows

# %%
df.duplicated().sum()
# Out:
# 1495

# %%
df = df.drop_duplicates()

# %%
len(df)
# Out:
# 16827

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 16827 entries, 0 to 18340
# Data columns (total 10 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Brand          16827 non-null  object
#  1   Model          16827 non-null  object
#  2   Variant        16827 non-null  object
#  3   Transmission   16827 non-null  object
#  4   KMs Driven     16827 non-null  int64
#  5   No. of Owners  16827 non-null  int64
#  6   Fuel Type      16827 non-null  object
#  7   City           16827 non-null  object
#  8   Price          16827 non-null  float64
#  9   Years Old      16827 non-null  int64
# dtypes: float64(1), int64(3), object(6)
# memory usage: 1.4+ MB

# %% [markdown]
# We see that we have 5 Categorical variables and 4 Numeric

# %%
df.describe()
# Out:
#          KMs Driven  No. of Owners         Price     Years Old
# count  1.682700e+04   16827.000000  1.682700e+04  16827.000000
# mean   5.777193e+04       1.299816  1.364192e+06      6.519819
# std    5.094181e+04       0.594081  1.942814e+06      3.637586
# min    0.000000e+00       0.000000  5.000000e+04      0.000000
# 25%    2.850000e+04       1.000000  4.350000e+05      4.000000
# 50%    5.097900e+04       1.000000  7.100000e+05      6.000000
# 75%    7.500000e+04       2.000000  1.550000e+06      9.000000
# max    1.500000e+06       5.000000  3.950000e+07     34.000000

# %% [markdown]
# ### Visualization

# %%
df
# Out:
#        Brand              Model                        Variant Transmission  \
# 0       Audi                 A4               2.0 TDI (143bhp)    Automatic
# 1       Audi                 A8                3.0 TDI quattro    Automatic
# 2       Audi                 Q3             2.0 TDI Base Grade    Automatic
# 3       Audi                 A3                 35 TDI Premium    Automatic
# 4       Audi                 Q3  35 TDI Premium Plus + Sunroof    Automatic
# ...      ...                ...                            ...          ...
# 18336  Volvo                S60                 T4 Inscription    Automatic
# 18337  Volvo               XC90                         D5 AWD    Automatic
# 18338  Volvo               XC60        Inscription [2017-2020]    Automatic
# 18339  Volvo  V90 Cross Country     D5 Inscription [2017-2020]    Automatic
# 18340  Volvo               XC60        Inscription [2017-2020]    Automatic
#
# ...

# %%
pivot = df.pivot_table(values='Price',index='Brand',aggfunc=(lambda x: x.mean()))
pivot = pivot.sort_values(by='Price',ascending=False)
pivot
# Out:
#                          Price
# Brand
# Rolls-Royce       2.088000e+07
# Lamborghini       1.803333e+07
# Bentley           1.105736e+07
# Hummer            8.725000e+06
# Lexus             7.405769e+06
# Maserati          7.324900e+06
# Aston Martin      6.760000e+06
# Porsche           6.229418e+06
# Land Rover        4.722398e+06
# Mercedes-Benz     3.862568e+06
# BMW               3.375548e+06
# Volvo             3.187045e+06
# Jaguar            3.073371e+06
# MINI              2.846650e+06
# Audi              2.490061e+06
# MG                1.926721e+06
# Isuzu             1.866000e+06
# Jeep              1.829595e+06
# Kia               1.586458e+06
# Toyota            1.337120e+06
# Skoda             1.005144e+06
# Mahindra          9.754596e+05
# Mitsubishi        9.454493e+05
# Ford              7.705500e+05
# Ssangyong         6.850000e+05
# Hyundai           6.679313e+05
# Tata              6.579393e+05
# Honda             6.315164e+05
# Volkswagen        6.146780e+05
# ...

# %%
plt.figure(figsize=(15,8))
sns.barplot(x = pivot.index,y=pivot['Price'],palette='cool')
plt.xticks(rotation=90)
plt.title('Brand vs Mean Price')
plt.show()

# %% [markdown]
# We see the mean price wise distribution of the brands.
#
#     - Rolls-Royce are the most expensive.
#     - Mahindra-Renault is the cheapest.

# %%
pivot = df.pivot_table(values='Price',index='Years Old',aggfunc=(lambda x: x.mean()))
pivot
# Out:
#                   Price
# Years Old
# 0          2.014480e+06
# 1          2.566212e+06
# 2          2.320620e+06
# 3          1.906691e+06
# 4          1.791499e+06
# 5          1.540383e+06
# 6          1.255173e+06
# 7          1.173333e+06
# 8          9.707540e+05
# 9          8.626850e+05
# 10         8.170200e+05
# 11         7.762470e+05
# 12         5.580547e+05
# 13         5.150258e+05
# 14         4.510000e+05
# 15         3.820934e+05
# 16         4.021519e+05
# 17         5.062065e+05
# 18         3.060000e+05
# 19         2.147712e+05
# 20         2.998333e+05
# 21         1.627500e+05
# 22         2.461111e+05
# 23         4.320000e+05
# 24         4.822500e+05
# 25         1.199500e+06
# 26         1.895000e+06
# 27         3.490000e+05
# 28         7.550000e+05
# 31         2.200000e+06
# 32         3.250000e+05
# 34         7.422500e+05

# %%
plt.figure(figsize=(15,8))
sns.barplot(x = pivot.index,y=pivot['Price'],palette='cool')
plt.title('Years Old vs Price')
plt.xticks(rotation=90)
plt.show()

# %%
temp = df[df['Years Old'] >= 21]
len(temp)
# Out:
# 37

# %% [markdown]
# We see a linear relation in the cars that are upto 23 years old.
#
# On further analysis we see that there are just 15 cars sold which are higher than 24 years old, which also happen to be mostly exotic cars because of which the avg price has a very high peak.
#
# We could drop them as it would affect our model adversly.

# %%
df = df[df['Years Old'] <= 21]
df
# Out:
#        Brand              Model                        Variant Transmission  \
# 0       Audi                 A4               2.0 TDI (143bhp)    Automatic
# 1       Audi                 A8                3.0 TDI quattro    Automatic
# 2       Audi                 Q3             2.0 TDI Base Grade    Automatic
# 3       Audi                 A3                 35 TDI Premium    Automatic
# 4       Audi                 Q3  35 TDI Premium Plus + Sunroof    Automatic
# ...      ...                ...                            ...          ...
# 18336  Volvo                S60                 T4 Inscription    Automatic
# 18337  Volvo               XC90                         D5 AWD    Automatic
# 18338  Volvo               XC60        Inscription [2017-2020]    Automatic
# 18339  Volvo  V90 Cross Country     D5 Inscription [2017-2020]    Automatic
# 18340  Volvo               XC60        Inscription [2017-2020]    Automatic
#
# ...

# %%
pivot = df.pivot_table(values='Price',index='Years Old',aggfunc=(lambda x: x.mean()))
pivot
# Out:
#                   Price
# Years Old
# 0          2.014480e+06
# 1          2.566212e+06
# 2          2.320620e+06
# 3          1.906691e+06
# 4          1.791499e+06
# 5          1.540383e+06
# 6          1.255173e+06
# 7          1.173333e+06
# 8          9.707540e+05
# 9          8.626850e+05
# 10         8.170200e+05
# 11         7.762470e+05
# 12         5.580547e+05
# 13         5.150258e+05
# 14         4.510000e+05
# 15         3.820934e+05
# 16         4.021519e+05
# 17         5.062065e+05
# 18         3.060000e+05
# 19         2.147712e+05
# 20         2.998333e+05
# 21         1.627500e+05

# %%
plt.figure(figsize=(15,8))
sns.barplot(x = pivot.index,y=pivot['Price'],palette='cool')
plt.title('Year vs Price')
plt.xticks(rotation=90)
plt.show()

# %%
pivot = df.pivot_table(values='Price',index='Transmission',aggfunc=(lambda x: x.mean()))
pivot
# Out:
#                      Price
# Transmission
# Automatic     2.496246e+06
# Manual        6.344657e+05

# %%
plt.figure(figsize=(8,6))
sns.barplot(x = pivot.index,y=pivot['Price'],palette='mako')
plt.title('Transmission vs Price')
plt.xticks(rotation=90)
plt.show()

# %%
plt.figure(figsize=(10,8))
sns.barplot(x=df['Years Old'],y=df['Price'],hue=df['Transmission'],palette='cool')
plt.show()

# %% [markdown]
# We see that the prices of Automatics are significantly higher than the Manuals

# %%
pivot = df.pivot_table(values='Price',index='Fuel Type',aggfunc=(lambda x: x.mean()))
pivot = pivot.sort_values(by='Price')
pivot
# Out:
#                      Price
# Fuel Type
# LPG           2.245000e+05
# Petrol + CNG  4.627848e+05
# CNG           4.825536e+05
# Petrol        1.080301e+06
# Diesel + CNG  1.080794e+06
# Diesel + LPG  1.181056e+06
# Petrol + LPG  1.569353e+06
# Diesel        1.663957e+06
# Hybrid        1.817032e+06
# Electric      1.819188e+06

# %%
plt.figure(figsize=(8,6))
sns.barplot(x = pivot.index,y=pivot['Price'],palette='cool')
plt.title('Fuel Type vs Price')
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# From above, we see that the Hybrid and Electric vehicles are the most expensive.

# %%
pivot = df.pivot_table(values='Price',index='City',aggfunc=(lambda x: x.mean()))
pivot = pivot.sort_values(by='Price')
pivot
# Out:
#                   Price
# City
# Ahmedabad  9.065650e+05
# Kolkata    9.101755e+05
# Hyderabad  1.082693e+06
# Pune       1.122371e+06
# Chennai    1.222419e+06
# Bengaluru  1.307547e+06
# Mumbai     1.554262e+06
# Delhi      2.003860e+06

# %%
plt.figure(figsize=(8,6))
sns.barplot(x = pivot.index,y=pivot['Price'],palette='cool')
plt.title('City vs Price')
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# We see that the the vehicle cost is Ahmedabad is the Cheapest and Delhi the highest

# %% [markdown]
# ### Checking Skewness

# %%
df.plot(kind='density',subplots=True,figsize=(15,10),layout=(2,2),sharex=False)
plt.show()

# %%
df.skew()
# Out:
# KMs Driven       7.911808
# No. of Owners    2.387841
# Price            5.604669
# Years Old        0.520197
# dtype: float64

# %% [markdown]
# Setting the skewness threshod as +/-0.5.We see right skewness in the data.
#
#     - KMs Driven
#     - No. of Owners
#     - Price
# The above mentioned features are above the skewness threshold but No. of Owners and Price can be ignored No. of Owners is a categorical variable and Price is Target Variable.

# %% [markdown]
# ### Checking Outliers

# %%
sns.boxplot(df['KMs Driven'],palette='mako')
plt.show()

# %%
sns.boxplot(df['Price'],palette='mako')
plt.show()

# %% [markdown]
# We see a lot of outliers in the price and KM's driven.

# %% [markdown]
# ### Encoding Categorical Variables

# %%
Obj_Columns = []
for i in df.dtypes.index:
    if df[i].dtypes=='O':
        Obj_Columns.append(i)
Obj_Columns
# Out:
# ['Brand', 'Model', 'Variant', 'Transmission', 'Fuel Type', 'City']

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()

# %%
for i in Obj_Columns:
    df[i] = le.fit_transform(df[i])

# %%
df
# Out:
#        Brand  Model  Variant  Transmission  KMs Driven  No. of Owners  \
# 0          1     17      283             0       48000              1
# 1          1     22      504             0       65000              1
# 2          1    220      288             0       69500              1
# 3          1     16      584             0       39254              2
# 4          1    220      587             0       86000              2
# ...      ...    ...      ...           ...         ...            ...
# 18336     37    244     2209             0       15000              1
# 18337     37    312     1054             0      135000              1
# 18338     37    311     1454             0       71500              2
# 18339     37    289     1057             0       55000              1
# 18340     37    311     1454             0       60000              1
#
#        Fuel Type  City      Price  Years Old
# 0              1     0  1690000.0          7
# ...

# %% [markdown]
# ### Removing Outliers

# %%
from scipy.stats import zscore

# %%
z = np.abs(zscore(df))
z.shape
# Out:
# (16798, 10)

# %%
df = df[(z<3).all(axis=1)]
df.shape
# Out:
# (16205, 10)

# %% [markdown]
# ### Data Loss

# %%
percentage_loss = (16798-16205)/16798*100

# %%
percentage_loss
# Out:
# 3.530182164543398

# %%
df = df.reset_index()
df.drop('index',axis=1,inplace=True)

# %%
df
# Out:
#        Brand  Model  Variant  Transmission  KMs Driven  No. of Owners  \
# 0          1     17      283             0       48000              1
# 1          1     22      504             0       65000              1
# 2          1    220      288             0       69500              1
# 3          1     16      584             0       39254              2
# 4          1    220      587             0       86000              2
# ...      ...    ...      ...           ...         ...            ...
# 16200     37    244     2209             0       15000              1
# 16201     37    312     1054             0      135000              1
# 16202     37    311     1454             0       71500              2
# 16203     37    289     1057             0       55000              1
# 16204     37    311     1454             0       60000              1
#
#        Fuel Type  City      Price  Years Old
# 0              1     0  1690000.0          7
# ...

# %% [markdown]
# ### Checking Correlation

# %%
df.corr()
# Out:
#                   Brand     Model   Variant  Transmission  KMs Driven  \
# Brand          1.000000  0.283320  0.043201      0.113530    0.058660
# Model          0.283320  1.000000  0.268369      0.116113    0.021486
# Variant        0.043201  0.268369  1.000000      0.175865   -0.148547
# Transmission   0.113530  0.116113  0.175865      1.000000    0.121503
# KMs Driven     0.058660  0.021486 -0.148547      0.121503    1.000000
# No. of Owners -0.052833 -0.030856 -0.106353     -0.011013    0.270424
# Fuel Type     -0.015021 -0.058907  0.101324      0.112706   -0.342111
# City           0.090376  0.025278 -0.006849     -0.066218   -0.036477
# Price         -0.105326 -0.081942 -0.138085     -0.577111   -0.220930
# Years Old     -0.079249 -0.035491 -0.234069      0.128803    0.572831
#
#                No. of Owners  Fuel Type      City     Price  Years Old
# Brand              -0.052833  -0.015021  0.090376 -0.105326  -0.079249
# ...

# %%
plt.figure(figsize=(15,10))
sns.heatmap(df.corr(),annot=True,fmt='.2f',cmap='cool')
plt.show()

# %% [markdown]
# We see Transmission has the highest negitive correlation with the Target.
#
# Most of the features are negitively correlated and City has 0 correlation, Hence we could consider dropping it.

# %% [markdown]
# ### Splitting the data into Features and Target

# %%
x = df.drop(['Price','City'],axis=1)
x.shape
# Out:
# (16205, 8)

# %%
y = df['Price']
y.shape
# Out:
# (16205,)

# %% [markdown]
# ### Normalizing the Data

# %%
from sklearn.preprocessing import power_transform

# %%
X = power_transform(x)
X = pd.DataFrame(X,columns=x.columns)
X
# Out:
#           Brand     Model   Variant  Transmission  KMs Driven  No. of Owners  \
# 0     -1.858226 -1.771912 -1.502510     -1.264036   -0.037841      -0.494071
# 1     -1.858226 -1.670860 -1.156676     -1.264036    0.425377      -0.494071
# 2     -1.858226  0.625417 -1.494141     -1.264036    0.537222      -0.494071
# 3     -1.858226 -1.793253 -1.040546     -1.264036   -0.309427       1.497657
# 4     -1.858226  0.625417 -1.036263     -1.264036    0.918471       1.497657
# ...         ...       ...       ...           ...         ...            ...
# 16200  1.460703  0.831834  0.906589     -1.264036   -1.295885      -0.494071
# 16201  1.460703  1.381365 -0.415187     -1.264036    1.868975      -0.494071
# 16202  1.460703  1.373608  0.067781     -1.264036    0.585739       1.497657
# 16203  1.460703  1.200680 -0.411428     -1.264036    0.161691      -0.494071
# 16204  1.460703  1.373608  0.067781     -1.264036    0.296350      -0.494071
#
#        Fuel Type  Years Old
# ...

# %%
X.skew()
# Out:
# Brand           -0.227846
# Model           -0.214344
# Variant         -0.359104
# Transmission    -0.472964
# KMs Driven      -0.040828
# No. of Owners   -0.514747
# Fuel Type       -0.025403
# Years Old       -0.052200
# dtype: float64

# %% [markdown]
# Skewness is within the threshold

# %% [markdown]
# ### Scalling the data

# %%
from sklearn.preprocessing import StandardScaler

# %%
sc = StandardScaler()
X = sc.fit_transform(X)
X = pd.DataFrame(X,columns=x.columns)
X
# Out:
#           Brand     Model   Variant  Transmission  KMs Driven  No. of Owners  \
# 0     -1.858226 -1.771912 -1.502510     -1.264036   -0.037841      -0.494071
# 1     -1.858226 -1.670860 -1.156676     -1.264036    0.425377      -0.494071
# 2     -1.858226  0.625417 -1.494141     -1.264036    0.537222      -0.494071
# 3     -1.858226 -1.793253 -1.040546     -1.264036   -0.309427       1.497657
# 4     -1.858226  0.625417 -1.036263     -1.264036    0.918471       1.497657
# ...         ...       ...       ...           ...         ...            ...
# 16200  1.460703  0.831834  0.906589     -1.264036   -1.295885      -0.494071
# 16201  1.460703  1.381365 -0.415187     -1.264036    1.868975      -0.494071
# 16202  1.460703  1.373608  0.067781     -1.264036    0.585739       1.497657
# 16203  1.460703  1.200680 -0.411428     -1.264036    0.161691      -0.494071
# 16204  1.460703  1.373608  0.067781     -1.264036    0.296350      -0.494071
#
#        Fuel Type  Years Old
# ...

# %% [markdown]
# ### Model Building

# %%
from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score,mean_absolute_error,mean_squared_error
from sklearn.linear_model import LinearRegression
lr = LinearRegression()

# %%
for i in range(0,100):
    x_train,x_test,y_train,y_test = train_test_split(X,y,test_size=0.3,random_state=i)
    lr.fit(x_train,y_train)
    pred_train = lr.predict(x_train)
    pred_test = lr.predict(x_test)
    print('At random_state',i,'the training accuracy is',r2_score(y_train,pred_train))
    print('At random_state',i,'the testing accuracy is',r2_score(y_test,pred_test))
    print()
# Out:
# At random_state 0 the training accuracy is 0.48007279659446334
# At random_state 0 the testing accuracy is 0.46212417752720514
#
# At random_state 1 the training accuracy is 0.480632674718813
# At random_state 1 the testing accuracy is 0.45972773721814053
#
# At random_state 2 the training accuracy is 0.4720391814386339
# At random_state 2 the testing accuracy is 0.4813576093241244
#
# At random_state 3 the training accuracy is 0.47548964272564487
# At random_state 3 the testing accuracy is 0.4732473418371259
#
# At random_state 4 the training accuracy is 0.47550325890850564
# At random_state 4 the testing accuracy is 0.4734288681285175
#
# At random_state 5 the training accuracy is 0.47822555298971725
# At random_state 5 the testing accuracy is 0.46694499269466794
#
# At random_state 6 the training accuracy is 0.4696708241711891
# At random_state 6 the testing accuracy is 0.48601913043744294
#
# At random_state 7 the training accuracy is 0.47803134068887965
# ...

# %%
x_train,x_test,y_train,y_test = train_test_split(X,y,test_size=0.3,random_state=94)
lr.fit(x_train,y_train)
pred_test = lr.predict(x_test)
print(r2_score(y_test,pred_test))
# Out:
# 0.47254326824670423

# %%
Training_Accuracy = r2_score(y_train,pred_train)
Testing_Accuracy = r2_score(y_test,pred_test)

from sklearn.model_selection import cross_val_score

for j in range(2,11):
    cv_score = cross_val_score(lr,X,y,cv=j)
    cv_mean = cv_score.mean()
    print(f"At cross fold {j} the cv score is {cv_mean} and the accuracy score for training is {Training_Accuracy} and the accuracy for testing is {Testing_Accuracy}")
    print()
# Out:
# At cross fold 2 the cv score is 0.4464131846120334 and the accuracy score for training is -0.4360037704298765 and the accuracy for testing is 0.47254326824670423
#
# At cross fold 3 the cv score is 0.45725745885628655 and the accuracy score for training is -0.4360037704298765 and the accuracy for testing is 0.47254326824670423
#
# At cross fold 4 the cv score is 0.4517164846437229 and the accuracy score for training is -0.4360037704298765 and the accuracy for testing is 0.47254326824670423
#
# At cross fold 5 the cv score is 0.4583992131074882 and the accuracy score for training is -0.4360037704298765 and the accuracy for testing is 0.47254326824670423
#
# At cross fold 6 the cv score is 0.4461646665493793 and the accuracy score for training is -0.4360037704298765 and the accuracy for testing is 0.47254326824670423
#
# At cross fold 7 the cv score is 0.45345156544646603 and the accuracy score for training is -0.4360037704298765 and the accuracy for testing is 0.47254326824670423
#
# ...

# %%
def Model_reg(model):
    model.fit(x_train,y_train)
    pred = model.predict(x_test)
    cv = cross_val_score(model,x,y,cv=5)
    cv_score = cv.mean()*100
    print('Model Report :-')
    print('RMSE',np.sqrt(mean_squared_error(y_test,pred)))
    print('MAE', mean_absolute_error(y_test,pred))
    r2_Score = r2_score(y_test,pred)*100
    print('r2_score :', r2_Score)
    print('cv_score :', cv_score)
    coef = pd.Series(model.coef_,X.columns).sort_values(ascending=False)
    coef.plot(kind='bar',title = 'Model Coefficient')
    print('Difference between r2_score and cv is ',r2_Score-cv_score)

# %%
Model_reg(lr)
# Out:
# Model Report :-
# RMSE 913636.8880079273
# MAE 598672.448471305
# r2_score : 47.25432682467042
# cv_score : 45.73828222628279
# Difference between r2_score and cv is  1.51604459838763

# %%
from sklearn.linear_model import Ridge
ridge = Ridge()
Model_reg(ridge)
# Out:
# Model Report :-
# RMSE 913637.6731891622
# MAE 598659.9907344144
# r2_score : 47.254236165172905
# cv_score : 45.739093776995105
# Difference between r2_score and cv is  1.5151423881778001

# %%
from sklearn.linear_model import Lasso
lasso = Lasso()
Model_reg(lasso)
# Out:
# Model Report :-
# RMSE 913636.9671607269
# MAE 598671.9806678155
# r2_score : 47.254317685442494
# cv_score : 45.738288895961475
# Difference between r2_score and cv is  1.5160287894810196

# %%
def Model_tree(model):
    model.fit(x_train,y_train)
    pred = model.predict(x_test)
    cv = cross_val_score(model,x,y,cv=5)
    cv_score = cv.mean()*100
    print('Model Report :-')
    print('RMSE',np.sqrt(mean_squared_error(y_test,pred)))
    print('MAE', mean_absolute_error(y_test,pred))
    r2_Score = r2_score(y_test,pred)*100
    print('r2_score :', r2_Score)
    print('cv_score :', cv_score)
    coef = pd.Series(model.feature_importances_,X.columns).sort_values(ascending=False)
    coef.plot(kind='bar',title = 'Model Coefficient')
    print('Difference between r2_score and cv is ',r2_Score-cv_score)

# %%
from sklearn.tree import DecisionTreeRegressor
dtc = DecisionTreeRegressor()
Model_tree(dtc)
# Out:
# Model Report :-
# RMSE 450156.669273796
# MAE 205168.00397641573
# r2_score : 87.19537201567415
# cv_score : 83.53188978890567
# Difference between r2_score and cv is  3.6634822267684797

# %%
from sklearn.ensemble import RandomForestRegressor
rf = RandomForestRegressor()
Model_tree(rf)
# Out:
# Model Report :-
# RMSE 345135.0408932915
# MAE 166965.78865722514
# r2_score : 92.47307312278703
# cv_score : 90.67620534809902
# Difference between r2_score and cv is  1.7968677746880104

# %%
from sklearn.ensemble import ExtraTreesRegressor
et = ExtraTreesRegressor()
Model_tree(et)
# Out:
# Model Report :-
# RMSE 351282.6958146908
# MAE 175989.19784245166
# r2_score : 92.20254096720792
# cv_score : 90.27574459558106
# Difference between r2_score and cv is  1.926796371626864

# %%
from sklearn.ensemble import GradientBoostingRegressor
gb = GradientBoostingRegressor()
Model_tree(gb)
# Out:
# Model Report :-
# RMSE 550309.4965664748
# MAE 328483.44503800396
# r2_score : 80.86389247771388
# cv_score : 79.18832629101288
# Difference between r2_score and cv is  1.6755661867009906

# %% [markdown]
# We see that the difference in the cv and the RMSE is the least for
#
#     - GradientBoostingRegressor
#     - ExtraTreesRegressor
#     - RandomForestRegressor

# %% [markdown]
# ### HyperParameter Tuning

# %%
from sklearn.model_selection import GridSearchCV

# %%
rf = RandomForestRegressor()
parameters = {'n_estimators': list(range(25,501,25)),
               'max_features': ['auto', 'sqrt'],
               'max_depth': [2,3,5,None],
               'min_samples_split': [1,2,3,4]}
gcv= GridSearchCV(rf,parameters,cv=5,n_jobs=-1)
gcv.fit(x_train,y_train)
gcv.best_params_
# Out:
# {'max_depth': None,
#  'max_features': 'auto',
#  'min_samples_split': 2,
#  'n_estimators': 500}

# %%
gcv.best_estimator_
# Out:
# RandomForestRegressor(n_estimators=500)

# %%
rf = gcv.best_estimator_
Model_tree(rf)
# Out:
# Model Report :-
# RMSE 344254.777773686
# MAE 166524.04638438683
# r2_score : 92.51141884833179
# cv_score : 90.85641322733026
# Difference between r2_score and cv is  1.6550056210015214

# %%
et = ExtraTreesRegressor()
parameters = {'n_estimators':list(range(10,150,10)),
             'max_depth':[None,3,5,7,10,15,20],
             'max_features':["auto", "sqrt", "log2"],
             'min_samples_split':[1,2,3,4,5,6],
             'min_samples_leaf':[1,2,3]}
gcv= GridSearchCV(et,parameters,cv=5,n_jobs=-1)
gcv.fit(x_train,y_train)
gcv.best_params_
# Out:
# {'max_depth': 20,
#  'max_features': 'auto',
#  'min_samples_leaf': 1,
#  'min_samples_split': 3,
#  'n_estimators': 100}

# %%
gcv.best_estimator_
# Out:
# ExtraTreesRegressor(max_depth=20, min_samples_split=3)

# %%
et = gcv.best_estimator_
Model_tree(et)
# Out:
# Model Report :-
# RMSE 350525.9702819158
# MAE 174686.35172395947
# r2_score : 92.23609901608233
# cv_score : 90.50099992758076
# Difference between r2_score and cv is  1.7350990885015705

# %%
gbr = GradientBoostingRegressor()

parameters = {'n_estimators':[10,20,50,75,90],
              'learning_rate':[0.001,0.01,0.1,0.3,0.6],
             'loss':['squared_error', 'absolute_error', 'huber', 'quantile'],
             'min_samples_split':[1,2,3,4,5,6],
              'max_depth':[2,3,4,6]}
gcv= GridSearchCV(gbr,parameters,cv=5,n_jobs=-1)
gcv.fit(x_train,y_train)
gcv.best_params_
# Out:
# {'learning_rate': 0.3,
#  'loss': 'squared_error',
#  'max_depth': 6,
#  'min_samples_split': 2,
#  'n_estimators': 90}

# %%
gcv.best_estimator_
# Out:
# GradientBoostingRegressor(learning_rate=0.3, max_depth=6, n_estimators=90)

# %%
gb = gcv.best_estimator_
Model_tree(gb)
# Out:
# Model Report :-
# RMSE 351984.43441892555
# MAE 178295.60107601323
# r2_score : 92.17135671918051
# cv_score : 91.800950283352
# Difference between r2_score and cv is  0.37040643582851374

# %% [markdown]
# ### Final Model: GradientBoostingRegressor

# %%
gb = gcv.best_estimator_

# %%
gb.fit(x_train,y_train)
pred = gb.predict(x_test)
cv = cross_val_score(gb,x,y,cv=5)
cv_score = cv.mean()*100
print('Model Report : ',gcv.best_estimator_)
print('RMSE',np.sqrt(mean_squared_error(y_test,pred)))
print('MAE', mean_absolute_error(y_test,pred))
r2_Score = r2_score(y_test,pred)*100
print('r2_score :', r2_Score)
print('cv_score :', cv_score)
coef = pd.Series(gb.feature_importances_,X.columns).sort_values(ascending=False)
coef.plot(kind='bar',title = 'Model Coefficient')
print('Difference between r2_score and cv is ',r2_Score-cv_score)
# Out:
# Model Report :  GradientBoostingRegressor(learning_rate=0.3, max_depth=6, n_estimators=90)
# RMSE 350958.7091668782
# MAE 177899.88335234672
# r2_score : 92.21691746601036
# cv_score : 91.77573869454856
# Difference between r2_score and cv is  0.44117877146179296

# %%
df_pred = pd.DataFrame()
df_pred['Actual']=y_test
df_pred['Prediction'] = pred
df_pred['% Difference'] = (df_pred['Actual']-df_pred['Prediction'])/df_pred['Actual']*100
df_pred
# Out:
#           Actual    Prediction  % Difference
# 237     360000.0  3.463790e+05      3.783597
# 9952   2000000.0  1.800285e+06      9.985748
# 14330  1595000.0  1.524577e+06      4.415234
# 10730   825000.0  1.047786e+06    -27.004400
# 3515   4100000.0  4.006618e+06      2.277608
# ...          ...           ...           ...
# 2080   1475000.0  1.252037e+06     15.116104
# 3137   2850000.0  2.958101e+06     -3.793000
# 8089    310000.0  3.584331e+05    -15.623587
# 14840   400000.0  4.070753e+05     -1.768828
# 614     525000.0  7.189841e+05    -36.949361
#
# [4862 rows x 3 columns]

# %%
plt.figure(figsize=(8,6))
plt.scatter(x=df_pred['Actual'],y = df_pred['Prediction'],color='r')
plt.plot(df_pred['Actual'],df_pred['Actual'],color='b')
plt.xlabel('Actual Price')
plt.ylabel('Predicted Price')
plt.show()

# %% [markdown]
# ### Saving the Model

# %%
import pickle

# %%
file_name = 'Car_Price_Prediction.pkl'
pickle.dump(gb,open(file_name,'wb'))
